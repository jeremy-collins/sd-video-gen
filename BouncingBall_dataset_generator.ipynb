# %%
# !git clone https://github.com/Visual-modelling/2D-bouncing.git
# Out:
# Cloning into '2D-bouncing'...
# remote: Enumerating objects: 321, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 321 (delta 34), reused 33 (delta 16), pack-reused 260
# Receiving objects: 100% (321/321), 317.30 KiB | 6.75 MiB/s, done.
# Resolving deltas: 100% (176/176), done.

# %%
# %cd 2D-bouncing/
# Out:
# /content/2D-bouncing

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 268 kB 5.3 MB/s
# ...
#      |████████████████████████████████| 7.1 MB 5.8 MB/s
# ...
#   Created wheel for PyYAML: filename=PyYAML-5.3-cp37-cp37m-linux_x86_64.whl size=44245 sha256=7bd5341e89f64a3e725c162e5304ddd683f4ccfaba83fffa5a196f6c187ca69e
#   Stored in directory: /root/.cache/pip/wheels/8a/55/a4/c0a81d27c33462cfdcb904db018f5550197e88b2b6b85beed2
# Successfully built PyYAML
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
# ...

# %%
# !pip freeze | grep scikit-learn
# Out:
# scikit-learn==0.22.2

# %%
# !apt install imagemagick
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-noto-mono ghostscript gsfonts
#   imagemagick-6-common imagemagick-6.q16 libcupsfilters1 libcupsimage2
#   libdjvulibre-text libdjvulibre21 libgs9 libgs9-common libijs-0.35
#   libjbig2dec0 liblqr-1-0 libmagickcore-6.q16-3 libmagickcore-6.q16-3-extra
#   libmagickwand-6.q16-3 libnetpbm10 libwmf0.2-7 netpbm poppler-data
# Suggested packages:
#   fonts-noto ghostscript-x imagemagick-doc autotrace cups-bsd | lpr | lprng
#   enscript gimp gnuplot grads hp2xx html2ps libwmf-bin mplayer povray radiance
#   sane-utils texlive-base-bin transfig ufraw-batch inkscape libjxr-tools
#   libwmf0.2-7-gtk poppler-utils fonts-japanese-mincho | fonts-ipafont-mincho
# ...

# %% [markdown]
# In the file 2D-Bouncing/srv/generate_dataset.py,
# Modify the code block below to the snippet in the next cell or as needed.
# ```
#
# # Default setting
#
# num_timesteps_per_simulation = 100
# image_size = 64
#
# # Parameters which can change per ball
# per_ball_parameter_space = {
#     "x":[0.1*i for i in range(1,10)],
#     "y":[0.1*i for i in range(1,10)],
#     "dx":[0.1*i for i in range(-5,5)],
#     "dy":[0.1*i for i in range(-5,5)],
#     "radius":[0.1*i for i in range(1,4)],
#     "foreground_color":['#{0:x}{0:x}{0:x}'.format(x) for x in range(15,-1,-1)],
# }
#
# # Global parameters
# parameter_space = {
#     "num_balls":range(1,4),
# #    "gx":[0.1*i for i in range(0,5)],
# #    "gy":[0.1*i for i in range(0,5)],
#     "background_color":['#{0:x}{0:x}{0:x}'.format(x) for x in range(0,16)],
# }
# ```

# %% [markdown]
# ```
# # Settings for generating Simplified version of dataset
# num_timesteps_per_simulation = 100
# image_size = 64
#
# # Parameters which can change per ball
# per_ball_parameter_space = {
#     "x":[0.1*i for i in range(1,10)],
#     "y":[0.1*i for i in range(1,10)],
#     "dx":[0.1*i for i in range(-5,5)],
#     "dy":[0.1*i for i in range(-5,5)],
#     "radius":[0.2],
#     "foreground_color":['#000'],
# }
#
# # Global parameters
# parameter_space = {
#     "num_balls":range(1,2),
# #    "gx":[0.1*i for i in range(0,5)],
# #    "gy":[0.1*i for i in range(0,5)],
#     "background_color":['#fff'],
# }
# ```

# %%
# !python src/generate_dataset.py 5000 test2_simple_bouncing_ball
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Simulation 1839 {'num_balls': 1, 'background_color': '#fff', 'x': [0.2], 'y': [0.6000000000000001], 'dx': [0.2], 'dy': [-0.4], 'radius': [0.2], 'foreground_color': ['#000']}
#
#
# Simulation 1840 {'num_balls': 1, 'background_color': '#fff', 'x': [0.7000000000000001], 'y': [0.2], 'dx': [-0.30000000000000004], 'dy': [-0.5], 'radius': [0.2], 'foreground_color': ['#000']}
#
#
# Rejecting: Too close to boundary!
# Rejecting: Too close to boundary!
# Rejecting: Too close to boundary!
# Rejecting: Too close to boundary!
# Simulation 1841 {'num_balls': 1, 'background_color': '#fff', 'x': [0.5], 'y': [0.7000000000000001], 'dx': [-0.2], 'dy': [-0.30000000000000004], 'radius': [0.2], 'foreground_color': ['#000']}
#
#
# Rejecting: Too close to boundary!
# ...

# %%
# !zip -r /content/sample_data/bouncing_ball_3000_blackwhite_simple1.zip /content/2D-bouncing/test2_simple_bouncing_ball/
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/2D-bouncing/test2_simple_bouncing_ball/2576/frame_036.png (deflated 7%)
#   adding: content/2D-bouncing/test2_simple_bouncing_ball/2576/frame_040.png (deflated 6%)
#   adding: content/2D-bouncing/test2_simple_bouncing_ball/2576/frame_033.png (deflated 6%)
#   adding: content/2D-bouncing/test2_simple_bouncing_ball/2576/frame_019.png (deflated 6%)
#   adding: content/2D-bouncing/test2_simple_bouncing_ball/2576/frame_029.png (deflated 7%)
#   adding: content/2D-bouncing/test2_simple_bouncing_ball/2576/frame_016.png (deflated 6%)
#   adding: content/2D-bouncing/test2_simple_bouncing_ball/2576/frame_061.png (deflated 7%)
#   adding: content/2D-bouncing/test2_simple_bouncing_ball/2576/frame_021.png (deflated 6%)
#   adding: content/2D-bouncing/test2_simple_bouncing_ball/1634/ (stored 0%)
#   adding: content/2D-bouncing/test2_simple_bouncing_ball/1634/frame_063.png (deflated 6%)
# ...
